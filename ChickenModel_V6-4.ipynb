# %% [markdown]
# <div style="font-family: 'Arial', sans-serif; margin: 0px; padding: 30px; background-color: #FFF3CD; border-left: 5px solid #FFECB3; border-radius: 50px;">
#     <h2 style="color: #856404; font-size: 24px; margin-top: 0;">🐔 Chickens and Eggs: A System Dynamics Model 🥚</h2>
#     <p style="color: #6c757d; font-size: 16px;">
#         Welcome to the interactive <strong>Chickens and Eggs</strong> model! This tool was designed by Robinson Salazar Rua and Peter Hovmand to help you understand the fascinating dynamics of a chicken population.
#     </p>
#     <p style="color: #6c757d; font-size: 16px;">
#         In this model, you'll explore how different factors (such as fertility rate, death risk, and capacity level) affect the population of chickens in our virtual farm.
#     </p>
#     <h3 style="color: #856404; font-size: 18px;"> Your Tasks:</h3>
#     <ul style="color: #6c757d; font-size: 16px;">
#         <li><strong>Adjust the Parameters:</strong> Use the sliders to change the model initial conditions.</li>
#         <li><strong>Observe the Changes:</strong> Watch how these adjustments impact the chicken population over time.</li>
#         <li><strong>Discover the Dynamics:</strong> Notice the feedback loops and delays that characterize this system.</li>
#     </ul>
#     <p style="color: #6c757d; font-size: 16px;">
#         By playing with these parameters, you'll gain insights into the principles of system dynamics and understand how even simple systems can exhibit complex behaviors. Enjoy your journey into the world of chickens and eggs!
#     </p>
# </div>

# %%
# !pip install pysd
# !pip install netCDF4
# !pip install voila
# Out:
# Requirement already satisfied: pysd in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (3.12.0)
# Requirement already satisfied: numpy<1.24 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from pysd) (1.23.5)
# Requirement already satisfied: pandas[excel] in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from pysd) (2.0.3)
# Requirement already satisfied: parsimonious in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from pysd) (0.10.0)
# Requirement already satisfied: xarray>=2023.9 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from pysd) (2023.12.0)
# Requirement already satisfied: lxml in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from pysd) (4.9.3)
# Requirement already satisfied: regex in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from pysd) (2022.7.9)
# Requirement already satisfied: chardet in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from pysd) (4.0.0)
# Requirement already satisfied: black in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from pysd) (0.0)
# Requirement already satisfied: openpyxl>=3.1 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from pysd) (3.1.2)
# Requirement already satisfied: scipy in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from pysd) (1.11.1)
# Requirement already satisfied: progressbar2 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from pysd) (4.2.0)
# Requirement already satisfied: portion in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from pysd) (2.4.2)
# Requirement already satisfied: et-xmlfile in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from openpyxl>=3.1->pysd) (1.1.0)
# Requirement already satisfied: packaging>=21.3 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from xarray>=2023.9->pysd) (23.1)
# Requirement already satisfied: click>=8.0.0 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from black->pysd) (8.0.4)
# Requirement already satisfied: mypy-extensions>=0.4.3 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from black->pysd) (1.0.0)
# Requirement already satisfied: pathspec>=0.9.0 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from black->pysd) (0.10.3)
# Requirement already satisfied: platformdirs>=2 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from black->pysd) (3.10.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from pandas[excel]->pysd) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from pandas[excel]->pysd) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from pandas[excel]->pysd) (2023.3)
# Requirement already satisfied: odfpy>=1.4.1 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from pandas[excel]->pysd) (1.4.1)
# Requirement already satisfied: pyxlsb>=1.0.8 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from pandas[excel]->pysd) (1.0.10)
# Requirement already satisfied: xlrd>=2.0.1 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from pandas[excel]->pysd) (2.0.1)
# Requirement already satisfied: xlsxwriter>=1.4.3 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from pandas[excel]->pysd) (3.1.9)
# Requirement already satisfied: sortedcontainers~=2.2 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from portion->pysd) (2.4.0)
# Requirement already satisfied: python-utils>=3.0.0 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from progressbar2->pysd) (3.8.1)
# Requirement already satisfied: colorama in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from click>=8.0.0->black->pysd) (0.4.6)
# Requirement already satisfied: defusedxml in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from odfpy>=1.4.1->pandas[excel]->pysd) (0.7.1)
# Requirement already satisfied: six>=1.5 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas[excel]->pysd) (1.16.0)
# Requirement already satisfied: typing-extensions>3.10.0.2 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from python-utils>=3.0.0->progressbar2->pysd) (4.7.1)
# Requirement already satisfied: netCDF4 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (1.6.5)
# Requirement already satisfied: cftime in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from netCDF4) (1.6.3)
# Requirement already satisfied: certifi in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from netCDF4) (2023.11.17)
# Requirement already satisfied: numpy in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from netCDF4) (1.23.5)
# Requirement already satisfied: voila in c:\users\rss188\appdata\roaming\python\python311\site-packages (0.5.5)
# Requirement already satisfied: jupyter-client<9,>=7.4.4 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from voila) (7.4.9)
# Requirement already satisfied: jupyter-core>=4.11.0 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from voila) (5.3.0)
# Requirement already satisfied: jupyter-server<3,>=2.0.0 in c:\users\rss188\appdata\roaming\python\python311\site-packages (from voila) (2.12.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.3.0 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from voila) (2.22.0)
# Requirement already satisfied: nbclient<0.8,>=0.4.0 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from voila) (0.5.13)
# Requirement already satisfied: nbconvert<8,>=6.4.5 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from voila) (6.5.4)
# Requirement already satisfied: traitlets<6,>=5.0.3 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from voila) (5.7.1)
# Requirement already satisfied: websockets>=9.0 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from voila) (12.0)
# Requirement already satisfied: entrypoints in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from jupyter-client<9,>=7.4.4->voila) (0.4)
# Requirement already satisfied: nest-asyncio>=1.5.4 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from jupyter-client<9,>=7.4.4->voila) (1.5.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from jupyter-client<9,>=7.4.4->voila) (2.8.2)
# Requirement already satisfied: pyzmq>=23.0 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from jupyter-client<9,>=7.4.4->voila) (25.1.2)
# Requirement already satisfied: tornado>=6.2 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from jupyter-client<9,>=7.4.4->voila) (6.3.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from jupyter-core>=4.11.0->voila) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from jupyter-core>=4.11.0->voila) (305.1)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from jupyter-server<3,>=2.0.0->voila) (3.5.0)
# Requirement already satisfied: argon2-cffi in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from jupyter-server<3,>=2.0.0->voila) (21.3.0)
# Requirement already satisfied: jinja2 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from jupyter-server<3,>=2.0.0->voila) (3.1.2)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\users\rss188\appdata\roaming\python\python311\site-packages (from jupyter-server<3,>=2.0.0->voila) (0.9.0)
# Requirement already satisfied: jupyter-server-terminals in c:\users\rss188\appdata\roaming\python\python311\site-packages (from jupyter-server<3,>=2.0.0->voila) (0.5.0)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from jupyter-server<3,>=2.0.0->voila) (5.9.2)
# Requirement already satisfied: overrides in c:\users\rss188\appdata\roaming\python\python311\site-packages (from jupyter-server<3,>=2.0.0->voila) (7.4.0)
# Requirement already satisfied: packaging in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from jupyter-server<3,>=2.0.0->voila) (23.1)
# Requirement already satisfied: prometheus-client in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from jupyter-server<3,>=2.0.0->voila) (0.14.1)
# Requirement already satisfied: pywinpty in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from jupyter-server<3,>=2.0.0->voila) (2.0.10)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from jupyter-server<3,>=2.0.0->voila) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from jupyter-server<3,>=2.0.0->voila) (0.17.1)
# Requirement already satisfied: websocket-client in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from jupyter-server<3,>=2.0.0->voila) (0.58.0)
# Requirement already satisfied: babel>=2.10 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.3.0->voila) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.3.0->voila) (0.9.6)
# Requirement already satisfied: jsonschema>=4.17.3 in c:\users\rss188\appdata\roaming\python\python311\site-packages (from jupyterlab-server<3,>=2.3.0->voila) (4.20.0)
# Requirement already satisfied: requests>=2.28 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.3.0->voila) (2.31.0)
# Requirement already satisfied: lxml in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (4.9.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (4.12.2)
# Requirement already satisfied: bleach in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (2.1.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (1.5.0)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (2.15.1)
# Requirement already satisfied: tinycss2 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (1.2.1)
# Requirement already satisfied: idna>=2.8 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.0.0->voila) (3.4)
# Requirement already satisfied: sniffio>=1.1 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.0.0->voila) (1.2.0)
# Requirement already satisfied: pytz>=2015.7 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from babel>=2.10->jupyterlab-server<3,>=2.3.0->voila) (2023.3.post1)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\rss188\appdata\roaming\python\python311\site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.3.0->voila) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\rss188\appdata\roaming\python\python311\site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.3.0->voila) (2023.11.2)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\rss188\appdata\roaming\python\python311\site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.3.0->voila) (0.32.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.3.0->voila) (0.14.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.0.0->voila) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.0.0->voila) (6.0)
# Requirement already satisfied: rfc3339-validator in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.0.0->voila) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.0.0->voila) (0.1.1)
# Requirement already satisfied: fastjsonschema in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.0.0->voila) (2.16.2)
# Requirement already satisfied: six>=1.5 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client<9,>=7.4.4->voila) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from requests>=2.28->jupyterlab-server<3,>=2.3.0->voila) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from requests>=2.28->jupyterlab-server<3,>=2.3.0->voila) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from requests>=2.28->jupyterlab-server<3,>=2.3.0->voila) (2023.11.17)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from argon2-cffi->jupyter-server<3,>=2.0.0->voila) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert<8,>=6.4.5->voila) (2.4)
# Requirement already satisfied: webencodings in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from bleach->nbconvert<8,>=6.4.5->voila) (0.5.1)
# Requirement already satisfied: fqdn in c:\users\rss188\appdata\roaming\python\python311\site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.3.0->voila) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\rss188\appdata\roaming\python\python311\site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.3.0->voila) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.3.0->voila) (2.1)
# Requirement already satisfied: uri-template in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.3.0->voila) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.3.0->voila) (1.13)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.0.0->voila) (1.15.1)
# Requirement already satisfied: pycparser in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.0.0->voila) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\rss188\appdata\local\anaconda3\lib\site-packages (from isoduration->jsonschema>=4.17.3->jupyterlab-server<3,>=2.3.0->voila) (1.2.3)

# %%
import os
import pysd
import itertools
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import ipywidgets as widgets
from ipywidgets import HBox, VBox, Layout
from IPython.display import display, HTML

# %%
os.chdir("C:/Users/rss188/Desktop/Chicken model/SFD chicken model")

# %%
def run_model(normal_fertility_rate, normal_death_risk, max_chicken_capacity, initial_chicken_population, initial_eggs_population):
    
    model= pysd.read_vensim("C:/Users/rss188/Desktop/Chicken model/SFD chicken model/SFD chicken model V2.mdl")
    params = {'Normal fertility rate': normal_fertility_rate, 'Normal death risk': normal_death_risk, 'Max chicken capacity': max_chicken_capacity, 'Initial chicken population':initial_chicken_population, 'Initial number of eggs':initial_eggs_population}
    return_columns = ['Chickens', 'Eggs', 'Births', 'Deaths']
    return_timestamps = range(51)

    results = model.run(params=params, return_columns=return_columns, return_timestamps=return_timestamps)
    
    display(HTML("<h2 style='margin: 0 0 15px 0; font-family: Comic Sans MS;'>Simulation Results</h2>"))
    
    results['Chickens'].plot(figsize=(10, 5))
    results['Eggs'].plot(figsize=(10, 5))
    plt.xlabel('Time (Days)')
    plt.ylabel('Number of Chickens and Eggs')
    plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
    plt.tight_layout()
    plt.show()
    
    results['Births'].plot(figsize=(10, 5), color='green', label='Births')
    results['Deaths'].plot(figsize=(10, 5), color='red', label='Deaths')
    plt.xlabel('Time (Days)')
    plt.ylabel('Number of Chickens per Day')
    plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
    plt.tight_layout()
    plt.show()   
    
    concatenated_results = pd.concat([results.head(6), results.tail(6)])
    concatenated_html = concatenated_results.to_html(classes='table table-striped')
    
    styled_html = f"""
    <div style='margin: auto; width: 100%; padding: 5px;'>
        {concatenated_html}
    </div>
    """
    display(HTML(styled_html))

# %%
# Create a title widget
title = HTML("<h2 style='margin: 0 0 15px 0; font-family: Comic Sans MS;'>Parameters</h2>")

# Common layout settings for all sliders
slider_layout = widgets.Layout(width='100%', height='100px', margin='0 0 5px 0')

# Slider style
slider_style = {'handle_color': '#856404', 'description_width': 'initial'}

# Define a custom style for the slider descriptions
description_style = {'description_font': 'Comic Sans MS'}

# Create the sliders
fertility_rate_slider = widgets.FloatSlider(
    value=0.2, min=0, max=1, step=0.01,
    description='Normal Fertility Rate', style=slider_style, layout=slider_layout, description_style=description_style
)

death_risk_slider = widgets.FloatSlider(
    value=0.2, min=0, max=1.0, step=0.01,
    description='Normal Death Risk', style=slider_style, layout=slider_layout, description_style=description_style
)

max_chicken_capacity_slider = widgets.FloatSlider(
    value=1000, min=0, max=2000, step=10,
    description='Max Chicken Capacity', style=slider_style, layout=slider_layout, description_style=description_style
)

initial_chicken_population_slider = widgets.FloatSlider(
    value=1000, min=0, max=4000, step=10,
    description='Initial Chicken Population', style=slider_style, layout=slider_layout, description_style=description_style
)

initial_eggs_population_slider = widgets.FloatSlider(
    value=1000, min=0, max=2000, step=10,
    description='Initial Number of Eggs', style=slider_style, layout=slider_layout, description_style=description_style
)

# Define the reset function
def reset_sliders(b):
    fertility_rate_slider.value = 0.2
    death_risk_slider.value = 0.2
    max_chicken_capacity_slider.value = 1000
    initial_chicken_population_slider.value = 1000
    initial_eggs_population_slider.value = 1000

# Create the reset button
reset_button = widgets.Button(
    description='Reset All',
    button_style='success', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Click here to reset all the inputs and outputs to their initial values',
    icon='refresh', # FontAwesome icon name
    layout=widgets.Layout(width='200px', height='40px', margin='10px')  # Adjust the width, height, and margin as needed
)

# Link the button to the reset function
reset_button.on_click(reset_sliders)

# Organize the sliders into two columns
left_column = widgets.VBox([fertility_rate_slider, death_risk_slider, max_chicken_capacity_slider], layout=slider_layout)
right_column = widgets.VBox([initial_chicken_population_slider, initial_eggs_population_slider], layout=slider_layout)

controls = HBox([left_column, right_column, reset_button])

# Link sliders to the model function
interactive_output_widget = widgets.interactive_output(run_model, {
    'normal_fertility_rate': fertility_rate_slider,
    'normal_death_risk': death_risk_slider,
    'max_chicken_capacity': max_chicken_capacity_slider,
    'initial_chicken_population': initial_chicken_population_slider,
    'initial_eggs_population': initial_eggs_population_slider
})

# Display the columns side by side
display(title, controls, interactive_output_widget)
# Out:
# <h2 style='margin: 0 0 15px 0; font-family: Comic Sans MS;'>Parameters</h2>
# HBox(children=(VBox(children=(FloatSlider(value=0.2, description='Normal Fertility Rate', layout=Layout(height…
# Output()
